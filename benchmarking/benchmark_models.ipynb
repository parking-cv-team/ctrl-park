# %% [markdown]
# # This script was ran in a Colab notebook, using the freely available T4 GPU

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 146.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from ultralytics import YOLO
from roboflow import Roboflow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# API keys censorship, the datasets are the same as indicated in the .pdf technical summary report

rf = Roboflow(api_key="")
project = rf.workspace("").project("")
dataset = project.version(1).download("yolo26")

project = rf.workspace("").project("")
dataset_cars = project.version(2).download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to People-1 in yolo26:: 100%|██████████| 5908/5908 [00:00<00:00, 10087.42it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Parking-Vehicles-2 in yolo26:: 100%|██████████| 4058/4058 [00:00<00:00, 4386.48it/s]

# %%
m_base = YOLO("yolo26s.pt")
m_car = YOLO("best_retrained.pt")
m_ped = YOLO("yolo26s_pedestriantuned.pt")

# %%
m_base.val(data="/content/Parking-Vehicles-2/data.yaml")
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 654.4±577.9 MB/s, size: 120.4 KB)
# val: Scanning /content/Parking-Vehicles-2/valid/labels.cache... 349 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 349/349 104.6Mit/s 0.0s
# val: /content/Parking-Vehicles-2/valid/images/0-0025_jpg.rf.195efa682a4e8b03fe6a1b8222d58e1d.jpg: 7 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        349       4278      0.005      0.192    0.00496    0.00311
#                 person        348       4213          0          0    0.00256   0.000933
#                    car         55         65       0.01      0.385    0.00735    0.00529
# Speed: 1.6ms preprocess, 7.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /content/runs/detect/val15
# ...

# %%
m_ped.val(data="/content/People-1/data.yaml")
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s summary (fused): 122 layers, 9,465,567 parameters, 0 gradients, 20.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 716.0±275.6 MB/s, size: 17.4 KB)
# val: Scanning /content/People-1/valid/labels.cache... 412 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 412/412 101.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 3.3it/s 7.8s
#                    all        412        744      0.921      0.853      0.928      0.688
# Speed: 2.2ms preprocess, 9.3ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c65382f0fb0>
# ...

# %%
m_car.model.names = {0: 'car', 1: 'motorcycle', 2: 'van'}

# %%
m_car.val(data="/content/Parking-Vehicles-2/data.yaml")
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1452.2±1034.3 MB/s, size: 150.5 KB)
# val: Scanning /content/Parking-Vehicles-2/valid/labels.cache... 349 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 349/349 97.6Mit/s 0.0s
# val: /content/Parking-Vehicles-2/valid/images/0-0025_jpg.rf.195efa682a4e8b03fe6a1b8222d58e1d.jpg: 7 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.5it/s 6.2s
#                    all        349       4278      0.689      0.696      0.694      0.511
#                    car        348       4213       0.79      0.931       0.94      0.679
#                    van         55         65      0.588       0.46      0.448      0.342
# Speed: 1.2ms preprocess, 7.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /content/runs/detect/val7
# ...

# %%
# !zip -r "/content/results.zip" "/content/runs"
# Out:
# updating: content/runs/ (stored 0%)
# updating: content/runs/detect/ (stored 0%)
# updating: content/runs/detect/val3/ (stored 0%)
# updating: content/runs/detect/val3/val_batch1_labels.jpg (deflated 5%)
# updating: content/runs/detect/val3/confusion_matrix.png (deflated 21%)
# updating: content/runs/detect/val3/val_batch0_labels.jpg (deflated 6%)
# updating: content/runs/detect/val3/val_batch2_pred.jpg (deflated 6%)
# updating: content/runs/detect/val3/BoxP_curve.png (deflated 21%)
# updating: content/runs/detect/val3/BoxR_curve.png (deflated 18%)
# updating: content/runs/detect/val3/confusion_matrix_normalized.png (deflated 21%)
# updating: content/runs/detect/val3/val_batch1_pred.jpg (deflated 6%)
# updating: content/runs/detect/val3/BoxPR_curve.png (deflated 28%)
# updating: content/runs/detect/val3/val_batch2_labels.jpg (deflated 5%)
# updating: content/runs/detect/val3/val_batch0_pred.jpg (deflated 6%)
# updating: content/runs/detect/val3/BoxF1_curve.png (deflated 29%)
# ...
