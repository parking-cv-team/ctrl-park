# %% [markdown]
# # This script was ran in a Colab notebook, using the freely available T4 GPU

# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 148.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
# API keys censorship, the datasets are the same as indicated in the .pdf technical summary report

from roboflow import Roboflow # API / IDs censorship
# rf = Roboflow(api_key="")
# project = rf.workspace("").project("")
dataset = project.version(1).download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to People-1 in yolo26:: 100%|██████████| 5908/5908 [00:02<00:00, 2481.75it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolo26s.pt')
results = model.train(data="/content/People-1/data.yaml", epochs=50, freeze=10)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r /content/file_NEW2.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train/results.csv (deflated 62%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 9%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train/labels.jpg (deflated 26%)
#   adding: content/runs/detect/train/train_batch6320.jpg (deflated 9%)
#   adding: content/runs/detect/train/train_batch6321.jpg (deflated 8%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 36%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 3%)
# ...
